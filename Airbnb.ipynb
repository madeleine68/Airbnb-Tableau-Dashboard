# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   1419   https://www.airbnb.com/rooms/1419  20210102020445   2021-01-02
# 1   8077   https://www.airbnb.com/rooms/8077  20210102020445   2021-01-04
# 2  12604  https://www.airbnb.com/rooms/12604  20210102020445   2021-01-02
# 3  23691  https://www.airbnb.com/rooms/23691  20210102020445   2021-01-03
# 4  27423  https://www.airbnb.com/rooms/27423  20210102020445   2021-01-05
#
#                                           name  \
# 0              Beautiful home in amazing area!
# 1           Downtown Harbourfront Private Room
# 2               Seaton Village Parlour Bedroom
# 3              Queen Bedroom close to downtown
# 4  Executive Studio Unit- Ideal for One Person
#
#                                          description  \
# 0  This large, family home is located in one of T...
# 1  Guest room in a luxury condo with access to al...
# 2  Comfortable sofa bed in airy main floor parlou...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18265 entries, 0 to 18264
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18265 non-null  int64
#  1   listing_url                                   18265 non-null  object
#  2   scrape_id                                     18265 non-null  int64
#  3   last_scraped                                  18265 non-null  object
#  4   name                                          18264 non-null  object
#  5   description                                   17581 non-null  object
#  6   neighborhood_overview                         11336 non-null  object
#  7   picture_url                                   18265 non-null  object
#  8   host_id                                       18265 non-null  int64
# ...

# %%
df.drop(["listing_url","scrape_id", "picture_url","host_id","host_url","host_thumbnail_url","host_picture_url", "reviews_per_month", ], axis=1,  inplace=True)

# %%
df.head()
# Out:
#       id last_scraped                                         name  \
# 0   1419   2021-01-02              Beautiful home in amazing area!
# 1   8077   2021-01-04           Downtown Harbourfront Private Room
# 2  12604   2021-01-02               Seaton Village Parlour Bedroom
# 3  23691   2021-01-03              Queen Bedroom close to downtown
# 4  27423   2021-01-05  Executive Studio Unit- Ideal for One Person
#
#                                          description  \
# 0  This large, family home is located in one of T...
# 1  Guest room in a luxury condo with access to al...
# 2  Comfortable sofa bed in airy main floor parlou...
# 3  <b>The space</b><br />Nestled in the middle of...
# 4  Brand new, fully furnished studio basement apa...
#
#                                neighborhood_overview       host_name  \
# 0  The apartment is located in the Ossington stri...       Alexandra
# 1                                                NaN  Kathie & Larry
# ...

# %%
df.to_csv("airbnb.csv")
